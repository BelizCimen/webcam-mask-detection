# %%
##DATA PREPROCESSİNG
# Out:
# {'with mask': 0, 'without mask': 1}
# ['with mask', 'without mask']
# [0, 1]
# {'with mask': 0, 'without mask': 1}
# ['with mask', 'without mask']
# [0, 1]

# %%
import cv2,os

data_path='dataset'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels))

print(label_dict)
print(categories)
print(labels)

# %%
img_size=100
data=[]
target=[]


for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
        
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)

        try:
            gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)           
            resized=cv2.resize(gray,(img_size,img_size))
            data.append(resized)
            target.append(label_dict[category])

        except Exception as e:
            print('Exception:',e)

# %%
import numpy as np

data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,1))
target=np.array(target)

from keras.utils import np_utils

new_target=np_utils.to_categorical(target)

# %%
np.save('data',data)
np.save('target',new_target)

# %%
##TRAINING CNN

# %%
import numpy as np

data=np.load('data.npy')
target=np.load('target.npy')

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

model.add(Conv2D(200,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(100,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(50,activation='relu'))

model.add(Dense(2,activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split

train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.1)

# %%
checkpoint = ModelCheckpoint('model-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
history=model.fit(train_data,train_target,epochs=20,callbacks=[checkpoint],validation_split=0.2)
# Out:
# Epoch 1/20
# Epoch 1/20
# 31/31 [==============================] - 75s 2s/step - loss: 0.7208 - accuracy: 0.5593 - val_loss: 0.5841 - val_accuracy: 0.7177
# 31/31 [==============================] - 75s 2s/step - loss: 0.7208 - accuracy: 0.5593 - val_loss: 0.5841 - val_accuracy: 0.7177
# INFO:tensorflow:Assets written to: model-001.model\assets
# INFO:tensorflow:Assets written to: model-001.model\assets
# Epoch 2/20
# Epoch 2/20
# 31/31 [==============================] - 72s 2s/step - loss: 0.5457 - accuracy: 0.7136 - val_loss: 0.4034 - val_accuracy: 0.8468
# 31/31 [==============================] - 72s 2s/step - loss: 0.5457 - accuracy: 0.7136 - val_loss: 0.4034 - val_accuracy: 0.8468
# INFO:tensorflow:Assets written to: model-002.model\assets
# INFO:tensorflow:Assets written to: model-002.model\assets
# Epoch 3/20
# Epoch 3/20
# 31/31 [==============================] - 72s 2s/step - loss: 0.3112 - accuracy: 0.8819 - val_loss: 0.2375 - val_accuracy: 0.9032
# 31/31 [==============================] - 72s 2s/step - loss: 0.3112 - accuracy: 0.8819 - val_loss: 0.2375 - val_accuracy: 0.9032
# INFO:tensorflow:Assets written to: model-003.model\assets
# INFO:tensorflow:Assets written to: model-003.model\assets
# Epoch 4/20
# Epoch 4/20
# 31/31 [==============================] - 73s 2s/step - loss: 0.2052 - accuracy: 0.9149 - val_loss: 0.2146 - val_accuracy: 0.9274
# 31/31 [==============================] - 73s 2s/step - loss: 0.2052 - accuracy: 0.9149 - val_loss: 0.2146 - val_accuracy: 0.9274
# INFO:tensorflow:Assets written to: model-004.model\assets
# INFO:tensorflow:Assets written to: model-004.model\assets
# Epoch 5/20
# Epoch 5/20
# 31/31 [==============================] - 72s 2s/step - loss: 0.1432 - accuracy: 0.9517 - val_loss: 0.1483 - val_accuracy: 0.9476
# 31/31 [==============================] - 72s 2s/step - loss: 0.1432 - accuracy: 0.9517 - val_loss: 0.1483 - val_accuracy: 0.9476
# INFO:tensorflow:Assets written to: model-005.model\assets
# INFO:tensorflow:Assets written to: model-005.model\assets
# Epoch 6/20
# Epoch 6/20
# 31/31 [==============================] - 72s 2s/step - loss: 0.0914 - accuracy: 0.9722 - val_loss: 0.1674 - val_accuracy: 0.9315
# 31/31 [==============================] - 72s 2s/step - loss: 0.0914 - accuracy: 0.9722 - val_loss: 0.1674 - val_accuracy: 0.9315
# Epoch 7/20
# Epoch 7/20
# 31/31 [==============================] - 73s 2s/step - loss: 0.0775 - accuracy: 0.9694 - val_loss: 0.1407 - val_accuracy: 0.9476
# 31/31 [==============================] - 73s 2s/step - loss: 0.0775 - accuracy: 0.9694 - val_loss: 0.1407 - val_accuracy: 0.9476
# INFO:tensorflow:Assets written to: model-007.model\assets
# INFO:tensorflow:Assets written to: model-007.model\assets
# Epoch 8/20
# Epoch 8/20
# 31/31 [==============================] - 70s 2s/step - loss: 0.0610 - accuracy: 0.9767 - val_loss: 0.1450 - val_accuracy: 0.9476
# 31/31 [==============================] - 70s 2s/step - loss: 0.0610 - accuracy: 0.9767 - val_loss: 0.1450 - val_accuracy: 0.9476
# Epoch 9/20
# Epoch 9/20
# 31/31 [==============================] - 73s 2s/step - loss: 0.0537 - accuracy: 0.9821 - val_loss: 0.1608 - val_accuracy: 0.9556
# 31/31 [==============================] - 73s 2s/step - loss: 0.0537 - accuracy: 0.9821 - val_loss: 0.1608 - val_accuracy: 0.9556
# Epoch 10/20
# Epoch 10/20
# 31/31 [==============================] - 74s 2s/step - loss: 0.0330 - accuracy: 0.9900 - val_loss: 0.1679 - val_accuracy: 0.9435
# 31/31 [==============================] - 74s 2s/step - loss: 0.0330 - accuracy: 0.9900 - val_loss: 0.1679 - val_accuracy: 0.9435
# Epoch 11/20
# Epoch 11/20
# 31/31 [==============================] - 75s 2s/step - loss: 0.0229 - accuracy: 0.9942 - val_loss: 0.1548 - val_accuracy: 0.9516
# 31/31 [==============================] - 75s 2s/step - loss: 0.0229 - accuracy: 0.9942 - val_loss: 0.1548 - val_accuracy: 0.9516
# Epoch 12/20
# Epoch 12/20
# 31/31 [==============================] - 73s 2s/step - loss: 0.0564 - accuracy: 0.9783 - val_loss: 0.1815 - val_accuracy: 0.9556
# 31/31 [==============================] - 73s 2s/step - loss: 0.0564 - accuracy: 0.9783 - val_loss: 0.1815 - val_accuracy: 0.9556
# Epoch 13/20
# Epoch 13/20
# 31/31 [==============================] - 79s 3s/step - loss: 0.0419 - accuracy: 0.9827 - val_loss: 0.3285 - val_accuracy: 0.9032
# 31/31 [==============================] - 79s 3s/step - loss: 0.0419 - accuracy: 0.9827 - val_loss: 0.3285 - val_accuracy: 0.9032
# Epoch 14/20
# Epoch 14/20
# 31/31 [==============================] - 78s 3s/step - loss: 0.0438 - accuracy: 0.9887 - val_loss: 0.1666 - val_accuracy: 0.9516
# 31/31 [==============================] - 78s 3s/step - loss: 0.0438 - accuracy: 0.9887 - val_loss: 0.1666 - val_accuracy: 0.9516
# Epoch 15/20
# Epoch 15/20
# 31/31 [==============================] - 74s 2s/step - loss: 0.0433 - accuracy: 0.9781 - val_loss: 0.1697 - val_accuracy: 0.9597
# 31/31 [==============================] - 74s 2s/step - loss: 0.0433 - accuracy: 0.9781 - val_loss: 0.1697 - val_accuracy: 0.9597
# Epoch 16/20
# Epoch 16/20
# 31/31 [==============================] - 72s 2s/step - loss: 0.0205 - accuracy: 0.9900 - val_loss: 0.1649 - val_accuracy: 0.9435
# 31/31 [==============================] - 72s 2s/step - loss: 0.0205 - accuracy: 0.9900 - val_loss: 0.1649 - val_accuracy: 0.9435
# Epoch 17/20
# Epoch 17/20
# 31/31 [==============================] - 70s 2s/step - loss: 0.0303 - accuracy: 0.9934 - val_loss: 0.1657 - val_accuracy: 0.9597
# 31/31 [==============================] - 70s 2s/step - loss: 0.0303 - accuracy: 0.9934 - val_loss: 0.1657 - val_accuracy: 0.9597
# Epoch 18/20
# Epoch 18/20
# 31/31 [==============================] - 76s 2s/step - loss: 0.0109 - accuracy: 0.9995 - val_loss: 0.1777 - val_accuracy: 0.9556
# 31/31 [==============================] - 76s 2s/step - loss: 0.0109 - accuracy: 0.9995 - val_loss: 0.1777 - val_accuracy: 0.9556
# Epoch 19/20
# Epoch 19/20
# 31/31 [==============================] - 72s 2s/step - loss: 0.0193 - accuracy: 0.9923 - val_loss: 0.1729 - val_accuracy: 0.9476
# 31/31 [==============================] - 72s 2s/step - loss: 0.0193 - accuracy: 0.9923 - val_loss: 0.1729 - val_accuracy: 0.9476
# Epoch 20/20
# Epoch 20/20
# 31/31 [==============================] - 72s 2s/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.1860 - val_accuracy: 0.9637
# 31/31 [==============================] - 72s 2s/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.1860 - val_accuracy: 0.9637

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['loss'],'r',label='training loss')
plt.plot(history.history['val_loss'],label='validation loss')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],'r',label='training accuracy')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
print(model.evaluate(test_data,test_target))
# Out:
# 5/5 [==============================] - 3s 477ms/step - loss: 0.1801 - accuracy: 0.9710
# 5/5 [==============================] - 3s 477ms/step - loss: 0.1801 - accuracy: 0.9710
# [0.1801498383283615, 0.9710144996643066]
# [0.1801498383283615, 0.9710144996643066]

# %%
##DETECT MASK

# %%
from keras.models import load_model
import cv2
import numpy as np

# %%
model = load_model('model-017.model')

face_clsfr=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

source=cv2.VideoCapture(0)

labels_dict={0:'MASK',1:'NO MASK'}
color_dict={0:(0,255,0),1:(0,0,255)}

# %%
while(True):

    ret,img=source.read()
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_clsfr.detectMultiScale(gray,1.3,5)  

    for x,y,w,h in faces:
    
        face_img=gray[y:y+w,x:x+w]
        resized=cv2.resize(face_img,(100,100))
        normalized=resized/255.0
        reshaped=np.reshape(normalized,(1,100,100,1))
        result=model.predict(reshaped)

        label=np.argmax(result,axis=1)[0]
      
        cv2.rectangle(img,(x,y),(x+w,y+h),color_dict[label],2)
        cv2.rectangle(img,(x,y-40),(x+w,y),color_dict[label],-1)
        cv2.putText(img, labels_dict[label], (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
        
        
    cv2.imshow('LIVE',img)
    key=cv2.waitKey(1)
    
    if(key==27):
        break
        
cv2.destroyAllWindows()
source.release()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-0d16338284e5> in <module>
#      11         normalized=resized/255.0
#      12         reshaped=np.reshape(normalized,(1,100,100,1))
# ---> 13         result=model.predict(reshaped)
#      14
#      15         label=np.argmax(result,axis=1)[0]
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1623       callbacks.on_predict_begin()
#    1624       batch_outputs = None
# -> 1625       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1626         with data_handler.catch_stop_iteration():
#    1627           for step in data_handler.steps():
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in enumerate_epochs(self)
#    1131     """Yields `(epoch, tf.data.Iterator)`."""
#    1132     with self._truncate_execution_to_epoch():
# -> 1133       data_iterator = iter(self._dataset)
#    1134       for epoch in range(self._initial_epoch, self._epochs):
#    1135         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __iter__(self)
#     420     if context.executing_eagerly() or ops.inside_function():
#     421       with ops.colocate_with(self._variant_tensor):
# --> 422         return iterator_ops.OwnedIterator(self)
#     423     else:
#     424       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in __init__(self, dataset, components, element_spec)
#     680       if (components is not None or element_spec is not None):
#     681         raise ValueError(error_message)
# --> 682       self._create_iterator(dataset)
#     683
#     684   def _create_iterator(self, dataset):
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in _create_iterator(self, dataset)
#     703               output_types=self._flat_output_types,
#     704               output_shapes=self._flat_output_shapes))
# --> 705       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     706       # Delete the resource when this object is deleted
#     707       self._resource_deleter = IteratorResourceDeleter(
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    2968   if tld.is_eager:
#    2969     try:
# -> 2970       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2971         _ctx, "MakeIterator", name, dataset, iterator)
#    2972       return _result
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-0d16338284e5> in <module>
#      11         normalized=resized/255.0
#      12         reshaped=np.reshape(normalized,(1,100,100,1))
# ---> 13         result=model.predict(reshaped)
#      14
#      15         label=np.argmax(result,axis=1)[0]
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1623       callbacks.on_predict_begin()
#    1624       batch_outputs = None
# -> 1625       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1626         with data_handler.catch_stop_iteration():
#    1627           for step in data_handler.steps():
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in enumerate_epochs(self)
#    1131     """Yields `(epoch, tf.data.Iterator)`."""
#    1132     with self._truncate_execution_to_epoch():
# -> 1133       data_iterator = iter(self._dataset)
#    1134       for epoch in range(self._initial_epoch, self._epochs):
#    1135         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __iter__(self)
#     420     if context.executing_eagerly() or ops.inside_function():
#     421       with ops.colocate_with(self._variant_tensor):
# --> 422         return iterator_ops.OwnedIterator(self)
#     423     else:
#     424       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in __init__(self, dataset, components, element_spec)
#     680       if (components is not None or element_spec is not None):
#     681         raise ValueError(error_message)
# --> 682       self._create_iterator(dataset)
#     683
#     684   def _create_iterator(self, dataset):
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in _create_iterator(self, dataset)
#     703               output_types=self._flat_output_types,
#     704               output_shapes=self._flat_output_shapes))
# --> 705       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     706       # Delete the resource when this object is deleted
#     707       self._resource_deleter = IteratorResourceDeleter(
#
# D:\Downloads\anaconda3\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    2968   if tld.is_eager:
#    2969     try:
# -> 2970       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2971         _ctx, "MakeIterator", name, dataset, iterator)
#    2972       return _result
#
# KeyboardInterrupt:
